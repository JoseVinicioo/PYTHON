# %%
#Instalaçao 
#!python -m pip install yfinance
#!pip install crewai
# !pip install crewai crewai-tools

# %%
#IMPORT DAS LIBS

import json
import os
from datetime import datetime
import yfinance as yf

import crewai
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[131], line 8
#       5 from datetime import datetime
#       6 import yfinance as yf
# ----> 8 import crewai
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\crewai\__init__.py:1
# ----> 1 from crewai.agent import Agent
#       2 from crewai.crew import Crew
#       3 from crewai.pipeline import Pipeline
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\crewai\agent.py:13
#      10 from langchain_openai import ChatOpenAI
#      11 from pydantic import Field, InstanceOf, PrivateAttr, model_validator
# ---> 13 from crewai.agents import CacheHandler, CrewAgentExecutor, CrewAgentParser
#      14 from crewai.agents.agent_builder.base_agent import BaseAgent
#      15 from crewai.memory.contextual.contextual_memory import ContextualMemory
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\crewai\agents\__init__.py:2
#       1 from .cache.cache_handler import CacheHandler
# ----> 2 from .executor import CrewAgentExecutor
#       3 from .parser import CrewAgentParser
#       4 from .tools_handler import ToolsHandler
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\crewai\agents\executor.py:19
#      16 from langchain.text_splitter import RecursiveCharacterTextSplitter
#      17 from langchain.chains.summarize import load_summarize_chain
# ---> 19 from crewai.agents.agent_builder.base_agent_executor_mixin import CrewAgentExecutorMixin
#      20 from crewai.agents.tools_handler import ToolsHandler
#      23 from crewai.tools.tool_usage import ToolUsage, ToolUsageErrorException
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\crewai\agents\agent_builder\base_agent_executor_mixin.py:5
#       2 from typing import TYPE_CHECKING, Optional
#       4 from crewai.memory.entity.entity_memory_item import EntityMemoryItem
# ----> 5 from crewai.memory.long_term.long_term_memory_item import LongTermMemoryItem
#       6 from crewai.utilities.converter import ConverterError
#       7 from crewai.utilities.evaluators.task_evaluator import TaskEvaluator
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\crewai\memory\__init__.py:1
# ----> 1 from .entity.entity_memory import EntityMemory
#       2 from .long_term.long_term_memory import LongTermMemory
#       3 from .short_term.short_term_memory import ShortTermMemory
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\crewai\memory\entity\entity_memory.py:3
#       1 from crewai.memory.entity.entity_memory_item import EntityMemoryItem
#       2 from crewai.memory.memory import Memory
# ----> 3 from crewai.memory.storage.rag_storage import RAGStorage
#       6 class EntityMemory(Memory):
#       7     """
#       8     EntityMemory class for managing structured information about entities
#       9     and their relationships using SQLite storage.
#      10     Inherits from the Memory class.
#      11     """
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\crewai\memory\storage\rag_storage.py:10
#       8 from crewai.memory.storage.interface import Storage
#       9 from crewai.utilities.paths import db_storage_path
# ---> 10 from embedchain import App
#      11 from embedchain.llm.base import BaseLlm
#      12 from embedchain.models.data_type import DataType
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\embedchain\__init__.py:5
#       1 import importlib.metadata
#       3 __version__ = importlib.metadata.version(__package__ or __name__)
# ----> 5 from embedchain.app import App  # noqa: F401
#       6 from embedchain.client import Client  # noqa: F401
#       7 from embedchain.pipeline import Pipeline  # noqa: F401
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\embedchain\app.py:22
#      13 from embedchain.cache import (
#      14     Config,
#      15     ExactMatchEvaluation,
#    (...)
#      19     gptcache_pre_function,
#      20 )
#      21 from embedchain.client import Client
# ---> 22 from embedchain.config import AppConfig, CacheConfig, ChunkerConfig, Mem0Config
#      23 from embedchain.core.db.database import get_session
#      24 from embedchain.core.db.models import DataSource
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\embedchain\config\__init__.py:4
#       1 # flake8: noqa: F401
#       3 from .add_config import AddConfig, ChunkerConfig
# ----> 4 from .app_config import AppConfig
#       5 from .base_config import BaseConfig
#       6 from .cache_config import CacheConfig
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\embedchain\config\app_config.py:5
#       1 from typing import Optional
#       3 from embedchain.helpers.json_serializable import register_deserializable
# ----> 5 from .base_app_config import BaseAppConfig
#       8 @register_deserializable
#       9 class AppConfig(BaseAppConfig):
#      10     """
#      11     Config to initialize an embedchain custom `App` instance, with extra config options.
#      12     """
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\embedchain\config\base_app_config.py:6
#       4 from embedchain.config.base_config import BaseConfig
#       5 from embedchain.helpers.json_serializable import JSONSerializable
# ----> 6 from embedchain.vectordb.base import BaseVectorDB
#       8 logger = logging.getLogger(__name__)
#      11 class BaseAppConfig(BaseConfig, JSONSerializable):
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\embedchain\vectordb\base.py:2
#       1 from embedchain.config.vector_db.base import BaseVectorDbConfig
# ----> 2 from embedchain.embedder.base import BaseEmbedder
#       3 from embedchain.helpers.json_serializable import JSONSerializable
#       6 class BaseVectorDB(JSONSerializable):
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\embedchain\embedder\base.py:7
#       4 from embedchain.config.embedder.base import BaseEmbedderConfig
#       6 try:
# ----> 7     from chromadb.api.types import Embeddable, EmbeddingFunction, Embeddings
#       8 except RuntimeError:
#       9     from embedchain.utils.misc import use_pysqlite3
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\chromadb\__init__.py:3
#       1 from typing import Dict, Optional
#       2 import logging
# ----> 3 from chromadb.api.client import Client as ClientCreator
#       4 from chromadb.api.client import AdminClient as AdminClientCreator
#       5 from chromadb.auth.token import TokenTransportHeader
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\chromadb\api\__init__.py:7
#       5 from overrides import override
#       6 from chromadb.config import DEFAULT_DATABASE, DEFAULT_TENANT
# ----> 7 from chromadb.api.models.Collection import Collection
#       8 from chromadb.api.types import (
#       9     CollectionMetadata,
#      10     Documents,
#    (...)
#      23     WhereDocument,
#      24 )
#      25 from chromadb.config import Component, Settings
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\chromadb\api\models\Collection.py:7
#       4 from pydantic import BaseModel, PrivateAttr
#       6 from uuid import UUID
# ----> 7 import chromadb.utils.embedding_functions as ef
#       9 from chromadb.api.types import (
#      10     URI,
#      11     CollectionMetadata,
#    (...)
#      47     validate_embedding_function,
#      48 )
#      49 import logging
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\chromadb\utils\embedding_functions.py:7
#       3 from functools import cached_property
#       5 from tenacity import stop_after_attempt, wait_random, retry, retry_if_exception
# ----> 7 from chromadb.api.types import (
#       8     Document,
#       9     Documents,
#      10     Embedding,
#      11     Image,
#      12     Images,
#      13     EmbeddingFunction,
#      14     Embeddings,
#      15     is_image,
#      16     is_document,
#      17 )
#      19 from pathlib import Path
#      20 import os
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\chromadb\api\types.py:102
#      98     return cast(Documents, target)
#     101 # Images
# --> 102 ImageDType = Union[np.uint, np.int_, np.float_]
#     103 Image = NDArray[ImageDType]
#     104 Images = List[Image]
#
# File c:\Users\vinic\OneDrive\Documentos\estudos\PYTHON\venv\Lib\site-packages\numpy\__init__.py:414, in __getattr__(attr)
#     411     if _wn.category is exceptions.RankWarning:
#     412         # Ignore other warnings, they may not be relevant (see gh-25433).
#     413         error_message = f"{_wn.category.__name__}: {str(_wn.message)}"
# --> 414         msg = (
#     415             "Polyfit sanity test emitted a warning, most likely due "
#     416             "to using a buggy Accelerate backend."
#     417             "\nIf you compiled yourself, more information is available at:"
#     418             "\nhttps://numpy.org/devdocs/building/index.html"
#     419             "\nOtherwise report this to the vendor "
#     420             "that provided NumPy.\n\n{}\n".format(error_message))
#     421         raise RuntimeError(msg)
#     422 del _wn
#
# AttributeError: `np.float_` was removed in the NumPy 2.0 release. Use `np.float64` instead.

# %%
def fetch_stock_price(ticket):
    stock = yf.download(ticket, start="2023-08-08", end="2024-08-08")
    return stock
